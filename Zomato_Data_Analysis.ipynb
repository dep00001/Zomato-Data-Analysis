# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("/content/enhanced_zomato_dataset_clean.csv")

df.head()
# Out:
#   Restaurant_Name  Dining_Rating  Delivery_Rating  Dining_Votes  \
# 0      Doner King            3.9              4.2            39
# 1      Doner King            3.9              4.2            39
# 2      Doner King            3.9              4.2            39
# 3      Doner King            3.9              4.2            39
# 4      Doner King            3.9              4.2            39
#
#    Delivery_Votes    Cuisine Place_Name        City                 Item_Name  \
# 0               0  Fast Food   Malakpet   Hyderabad       Platter Kebab Combo
# 1               0  Fast Food   Malakpet   Hyderabad   Chicken Rumali Shawarma
# 2               0  Fast Food   Malakpet   Hyderabad    Chicken Tandoori Salad
# 3               0  Fast Food   Malakpet   Hyderabad         Chicken BBQ Salad
# 4               0  Fast Food   Malakpet   Hyderabad  Special Doner Wrap Combo
#
#   Best_Seller  ...  Is_Bestseller  Restaurant_Popularity  \
# ...

# %%
df.shape
# Out:
# (123657, 26)

# %%
df.columns
# Out:
# Index(['Restaurant_Name', 'Dining_Rating', 'Delivery_Rating', 'Dining_Votes',
#        'Delivery_Votes', 'Cuisine', 'Place_Name', 'City', 'Item_Name',
#        'Best_Seller', 'Votes', 'Prices', 'Average_Rating', 'Total_Votes',
#        'Price_per_Vote', 'Log_Price', 'Is_Bestseller', 'Restaurant_Popularity',
#        'Avg_Rating_Restaurant', 'Avg_Price_Restaurant', 'Avg_Rating_Cuisine',
#        'Avg_Price_Cuisine', 'Avg_Rating_City', 'Avg_Price_City',
#        'Is_Highly_Rated', 'Is_Expensive'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123657 entries, 0 to 123656
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Restaurant_Name        123657 non-null  object
#  1   Dining_Rating          123657 non-null  float64
#  2   Delivery_Rating        123657 non-null  float64
#  3   Dining_Votes           123657 non-null  int64
#  4   Delivery_Votes         123657 non-null  int64
#  5   Cuisine                123657 non-null  object
#  6   Place_Name             123657 non-null  object
#  7   City                   123657 non-null  object
#  8   Item_Name              123657 non-null  object
#  9   Best_Seller            123657 non-null  object
#  10  Votes                  123657 non-null  int64
#  11  Prices                 123657 non-null  float64
#  12  Average_Rating         123657 non-null  float64
#  13  Total_Votes            123657 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant_Name          0
# Dining_Rating            0
# Delivery_Rating          0
# Dining_Votes             0
# Delivery_Votes           0
# Cuisine                  0
# Place_Name               0
# City                     0
# Item_Name                0
# Best_Seller              0
# Votes                    0
# Prices                   0
# Average_Rating           0
# Total_Votes              0
# Price_per_Vote           0
# Log_Price                0
# Is_Bestseller            0
# Restaurant_Popularity    0
# Avg_Rating_Restaurant    0
# Avg_Price_Restaurant     0
# Avg_Rating_Cuisine       0
# Avg_Price_Cuisine        0
# Avg_Rating_City          0
# Avg_Price_City           0
# Is_Highly_Rated          0
# Is_Expensive             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(22127)

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#        Dining_Rating  Delivery_Rating   Dining_Votes  Delivery_Votes  \
# count  101530.000000    101530.000000  101530.000000   101530.000000
# mean        3.821385         3.959565     151.559726      116.704009
# std         0.350058         0.244990     230.662157      243.856446
# min         2.500000         2.500000       0.000000        0.000000
# 25%         3.700000         3.800000       0.000000        0.000000
# 50%         3.822264         4.000000      30.000000        0.000000
# 75%         4.000000         4.100000     221.000000       37.000000
# max         4.800000         4.600000     997.000000      983.000000
#
#                Votes         Prices  Average_Rating    Total_Votes  \
# count  101530.000000  101530.000000   101530.000000  101530.000000
# mean       19.110371     243.690758        3.890475     268.263735
# std       108.264166     197.534461        0.238118     291.518139
# min         0.000000       0.950000        3.000000       0.000000
# ...

# %%
df['City'].value_counts().head(10)
# Out:
# City
# Hyderabad    13100
# Mumbai       11640
# Chennai      11147
# Jaipur       11009
# Bangalore     9450
# Ahmedabad     8519
# Kolkata       6955
# Pune          6655
# Kochi         6281
# Raipur        6272
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.countplot(data=df, x='City')
plt.xticks(rotation=90)
plt.title("Restaurants in Each City")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Aggregate rating'], bins=20)
plt.title("Rating Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Aggregate rating'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_308/3244991401.py in <cell line: 0>()
#       1 plt.figure(figsize=(8,5))
# ...

# %%
df.columns
# Out:
# Index(['Restaurant_Name', 'Dining_Rating', 'Delivery_Rating', 'Dining_Votes',
#        'Delivery_Votes', 'Cuisine', 'Place_Name', 'City', 'Item_Name',
#        'Best_Seller', 'Votes', 'Prices', 'Average_Rating', 'Total_Votes',
#        'Price_per_Vote', 'Log_Price', 'Is_Bestseller', 'Restaurant_Popularity',
#        'Avg_Rating_Restaurant', 'Avg_Price_Restaurant', 'Avg_Rating_Cuisine',
#        'Avg_Price_Cuisine', 'Avg_Rating_City', 'Avg_Price_City',
#        'Is_Highly_Rated', 'Is_Expensive'],
#       dtype='object')

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Average_Rating'], bins=20)
plt.title("Rating Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Prices', y='Average_Rating', data=df)
plt.title("Price vs Rating")
plt.show()

# %%
df['City'].value_counts().head(10)
# Out:
# City
# Hyderabad    13100
# Mumbai       11640
# Chennai      11147
# Jaipur       11009
# Bangalore     9450
# Ahmedabad     8519
# Kolkata       6955
# Pune          6655
# Kochi         6281
# Raipur        6272
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='City')
plt.xticks(rotation=90)
plt.title("Restaurants per City")
plt.show()

# %%
df['Cuisine'].value_counts().head(10)
# Out:
# Cuisine
# Beverages       32818
# Pizza           12383
# Desserts         9285
# Fast Food        9268
# Chinese          5066
# Sichuan          4812
# Biryani          3462
# Shake            2784
# North Indian     2436
# Street Food      2371
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, y='Cuisine', order=df['Cuisine'].value_counts().index[:10])
plt.title("Top 10 Cuisines")
plt.show()

# %%
top_restaurants = df.sort_values(by='Average_Rating', ascending=False)

top_restaurants[['Restaurant Name','City','Average_Rating']].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_308/196251851.py in <cell line: 0>()
#       1 top_restaurants = df.sort_values(by='Average_Rating', ascending=False)
#       2
# ----> 3 top_restaurants[['Restaurant Name','City','Average_Rating']].head(10)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
df.columns = df.columns.str.strip()

# %%
top_restaurants = df.sort_values(by='Average_Rating', ascending=False)
top_restaurants[['Restaurant Name','City','Average_Rating']].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_308/1806278470.py in <cell line: 0>()
#       1 top_restaurants = df.sort_values(by='Average_Rating', ascending=False)
# ----> 2 top_restaurants[['Restaurant Name','City','Average_Rating']].head(10)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
# ...

# %%
top_restaurants = df.sort_values(by='Average_Rating', ascending=False)

top_restaurants[['Restaurant_Name','City','Average_Rating']].head(10)
# Out:
#           Restaurant_Name        City  Average_Rating
# 106321  Natural Ice Cream   New Delhi            4.65
# 106323  Natural Ice Cream   New Delhi            4.65
# 106324  Natural Ice Cream   New Delhi            4.65
# 106325  Natural Ice Cream   New Delhi            4.65
# 106328  Natural Ice Cream   New Delhi            4.65
# 106329  Natural Ice Cream   New Delhi            4.65
# 106308  Natural Ice Cream   New Delhi            4.65
# 106309  Natural Ice Cream   New Delhi            4.65
# 106326  Natural Ice Cream   New Delhi            4.65
# 106327  Natural Ice Cream   New Delhi            4.65

# %%
df['City'].value_counts().head(10)
# Out:
# City
# Hyderabad    13100
# Mumbai       11640
# Chennai      11147
# Jaipur       11009
# Bangalore     9450
# Ahmedabad     8519
# Kolkata       6955
# Pune          6655
# Kochi         6281
# Raipur        6272
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, y='City', order=df['City'].value_counts().index[:10])
plt.title("Top Cities with Restaurants")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['float64','int64'])

plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
df[df['Average_Rating'] >= 4].shape
# Out:
# (37377, 26)

# %%
high_rated = df[df['Average_Rating'] >= 4]

high_rated[['Restaurant_Name','City','Average_Rating']].head(10)
# Out:
#   Restaurant_Name        City  Average_Rating
# 0      Doner King   Hyderabad            4.05
# 1      Doner King   Hyderabad            4.05
# 2      Doner King   Hyderabad            4.05
# 3      Doner King   Hyderabad            4.05
# 4      Doner King   Hyderabad            4.05
# 5      Doner King   Hyderabad            4.05
# 6      Doner King   Hyderabad            4.05
# 7      Doner King   Hyderabad            4.05
# 8      Doner King   Hyderabad            4.05
# 9      Doner King   Hyderabad            4.05

# %% [markdown]
# Project Insights
#
# 1. Most restaurants have ratings between 3.5 and 4.5.
# 2. Some cities have significantly more restaurants.
# 3. Price has moderate correlation with restaurant ratings.
# 4. Certain cuisines dominate the restaurant market.
# 5. Highly rated restaurants tend to receive more votes.
